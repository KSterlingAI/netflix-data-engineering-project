# %%
df = spark.table("workspace.default.netflix_titles")

display(df)

# %% [markdown]
# Guardar BRONZE

# %%
df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("bronze.netflix_titles")

# %% [markdown]
# Verificar BRONZE

# %%
spark.sql("SELECT * FROM bronze.netflix_titles LIMIT 10").show()
