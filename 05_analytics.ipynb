# %% [markdown]
# Query 1 — Top países

# %%
# %sql
SELECT *
FROM gold.country_summary
LIMIT 10

# %% [markdown]
# Query 2 — Movies vs TV Shows

# %%
# %sql
SELECT *
FROM gold.content_summary

# %% [markdown]
# Query 3 — Releases por año

# %%
# %sql
SELECT *
FROM gold.year_summary
ORDER BY release_year DESC
